# %%
# !git clone https://github.com/endoflife-date/endoflife.date.git
# Out:
# Cloning into 'endoflife.date'...
# remote: Enumerating objects: 43732, done.
# remote: Counting objects: 100% (398/398), done.
# remote: Compressing objects: 100% (265/265), done.
# remote: Total 43732 (delta 286), reused 136 (delta 132), pack-reused 43334 (from 4)
# Receiving objects: 100% (43732/43732), 10.94 MiB | 8.59 MiB/s, done.
# Resolving deltas: 100% (34326/34326), done.

# %%
import frontmatter
from pathlib import Path

def parse_eol_markdown(path="endoflife.date/products"):
    entries = []
    for file in Path(path).glob("*.md"):
        post = frontmatter.load(file)
        product = post.get("title", file.stem)
        for release in post.get("releases", []):
            cycle = release.get("releaseCycle", release.get("cycle", "unknown"))
            release_date = release.get("releaseDate", "unknown")
            eol = release.get("eol", "unknown")
            if isinstance(eol, bool):
                eol = "TBD" if eol is False else str(eol)
            latest = release.get("latest", "")
            lts = release.get("lts", False)

            description = (
                f"{product} {cycle}, released on {release_date}, "
                f"reaches EOL on {eol}."
            )

            entries.append({
                "product": product,
                "cycle": cycle,
                "release": release_date,
                "eol": eol,
                "latest": latest,
                "lts": lts,
                "description": description
            })
    return entries

# %%
data=parse_eol_markdown()

# %%
list(filter(lambda x:(x['product']).lower().startswith('red'),data))
# Out:
# [{'product': 'Red Hat Satellite',
#   'cycle': '6.17',
#   'release': datetime.date(2025, 5, 6),
#   'eol': 'TBD',
#   'latest': '6.17.1',
#   'lts': False,
#   'description': 'Red Hat Satellite 6.17, released on 2025-05-06, reaches EOL on TBD.'},
#  {'product': 'Red Hat Satellite',
#   'cycle': '6.16',
#   'release': datetime.date(2024, 11, 5),
#   'eol': datetime.date(2026, 5, 31),
#   'latest': '6.16.5.2',
#   'lts': False,
#   'description': 'Red Hat Satellite 6.16, released on 2024-11-05, reaches EOL on 2026-05-31.'},
#  {'product': 'Red Hat Satellite',
#   'cycle': '6.15',
#   'release': datetime.date(2024, 4, 23),
#   'eol': datetime.date(2025, 11, 30),
#   'latest': '6.15.5.3',
#   'lts': False,
#   'description': 'Red Hat Satellite 6.15, released on 2024-04-23, reaches EOL on 2025-11-30.'},
#  {'product': 'Red Hat Satellite',
#   'cycle': '6.14',
#   'release': datetime.date(2023, 11, 8),
#   'eol': datetime.date(2025, 5, 31),
#   'latest': '6.14.4.5',
#   'lts': False,
#   'description': 'Red Hat Satellite 6.14, released on 2023-11-08, reaches EOL on 2025-05-31.'},
#  {'product': 'Red Hat Satellite',
#   'cycle': '6.13',
#   'release': datetime.date(2023, 5, 3),
#   'eol': datetime.date(2024, 11, 30),
#   'latest': '6.13.7.3',
#   'lts': False,
#   'description': 'Red Hat Satellite 6.13, released on 2023-05-03, reaches EOL on 2024-11-30.'},
#  {'product': 'Red Hat Satellite',
#   'cycle': '6.12',
#   'release': datetime.date(2022, 11, 16),
#   'eol': datetime.date(2024, 5, 31),
#   'latest': '6.12.5.3',
#   'lts': False,
#   'description': 'Red Hat Satellite 6.12, released on 2022-11-16, reaches EOL on 2024-05-31.'},
#  {'product': 'Red Hat Satellite',
#   'cycle': '6.11',
#   'release': datetime.date(2022, 7, 5),
#   'eol': datetime.date(2024, 1, 31),
#   'latest': '6.11.5.7',
#   'lts': False,
#   'description': 'Red Hat Satellite 6.11, released on 2022-07-05, reaches EOL on 2024-01-31.'},
#  {'product': 'Red Hat Satellite',
#   'cycle': '6.10',
#   'release': datetime.date(2021, 11, 16),
#   'eol': datetime.date(2023, 5, 31),
#   'latest': '6.10.7.2',
#   'lts': False,
#   'description': 'Red Hat Satellite 6.10, released on 2021-11-16, reaches EOL on 2023-05-31.'},
#  {'product': 'Red Hat Satellite',
#   'cycle': '6.9',
#   'release': datetime.date(2021, 4, 21),
#   'eol': datetime.date(2022, 11, 30),
#   'latest': '6.9.10',
#   'lts': False,
#   'description': 'Red Hat Satellite 6.9, released on 2021-04-21, reaches EOL on 2022-11-30.'},
#  {'product': 'Red Hat Satellite',
#   'cycle': '6.8',
#   'release': datetime.date(2020, 10, 27),
#   'eol': datetime.date(2022, 7, 31),
#   'latest': '6.8.6',
#   'lts': False,
#   'description': 'Red Hat Satellite 6.8, released on 2020-10-27, reaches EOL on 2022-07-31.'},
#  {'product': 'Red Hat Satellite',
#   'cycle': '6.7',
#   'release': datetime.date(2020, 4, 14),
#   'eol': datetime.date(2021, 11, 30),
#   'latest': '6.7.5',
#   'lts': False,
#   'description': 'Red Hat Satellite 6.7, released on 2020-04-14, reaches EOL on 2021-11-30.'},
#  {'product': 'Red Hat Satellite',
#   'cycle': '6.6',
#   'release': datetime.date(2019, 10, 22),
#   'eol': datetime.date(2021, 5, 14),
#   'latest': '6.6.3',
#   'lts': False,
#   'description': 'Red Hat Satellite 6.6, released on 2019-10-22, reaches EOL on 2021-05-14.'},
#  {'product': 'Red Hat Satellite',
#   'cycle': '6.5',
#   'release': datetime.date(2019, 5, 14),
#   'eol': datetime.date(2020, 10, 31),
#   'latest': '6.5.3',
#   'lts': False,
#   'description': 'Red Hat Satellite 6.5, released on 2019-05-14, reaches EOL on 2020-10-31.'},
#  {'product': 'Red Hat Satellite',
#   'cycle': '6.4',
#   'release': datetime.date(2018, 10, 16),
#   'eol': datetime.date(2020, 4, 30),
#   'latest': '6.4.4',
#   'lts': False,
#   'description': 'Red Hat Satellite 6.4, released on 2018-10-16, reaches EOL on 2020-04-30.'},
#  {'product': 'Red Hat Satellite',
#   'cycle': '6.3',
#   'release': datetime.date(2018, 2, 21),
#   'eol': datetime.date(2019, 5, 31),
#   'latest': '6.3.5',
#   'lts': False,
#   'description': 'Red Hat Satellite 6.3, released on 2018-02-21, reaches EOL on 2019-05-31.'},
#  {'product': 'Red Hat Satellite',
#   'cycle': '6.2',
#   'release': datetime.date(2016, 7, 27),
#   'eol': datetime.date(2019, 5, 31),
#   'latest': '6.2.16',
#   'lts': False,
#   'description': 'Red Hat Satellite 6.2, released on 2016-07-27, reaches EOL on 2019-05-31.'},
#  {'product': 'Red Hat Satellite',
#   'cycle': '6.1',
#   'release': datetime.date(2015, 8, 12),
#   'eol': datetime.date(2018, 10, 30),
#   'latest': '6.1.12',
#   'lts': False,
#   'description': 'Red Hat Satellite 6.1, released on 2015-08-12, reaches EOL on 2018-10-30.'},
#  {'product': 'Red Hat Satellite',
#   'cycle': '6.0',
#   'release': datetime.date(2014, 9, 10),
#   'eol': datetime.date(2018, 2, 21),
#   'latest': '6.0.8',
#   'lts': False,
#   'description': 'Red Hat Satellite 6.0, released on 2014-09-10, reaches EOL on 2018-02-21.'},
#  {'product': 'Redmine',
#   'cycle': '6.0',
#   'release': datetime.date(2024, 11, 10),
#   'eol': 'TBD',
#   'latest': '6.0.6',
#   'lts': False,
#   'description': 'Redmine 6.0, released on 2024-11-10, reaches EOL on TBD.'},
#  {'product': 'Redmine',
#   'cycle': '5.1',
#   'release': datetime.date(2023, 10, 31),
#   'eol': 'TBD',
#   'latest': '5.1.9',
#   'lts': False,
#   'description': 'Redmine 5.1, released on 2023-10-31, reaches EOL on TBD.'},
#  {'product': 'Redmine',
#   'cycle': '5.0',
#   'release': datetime.date(2022, 3, 28),
#   'eol': 'TBD',
#   'latest': '5.0.13',
#   'lts': False,
#   'description': 'Redmine 5.0, released on 2022-03-28, reaches EOL on TBD.'},
#  {'product': 'Redmine',
#   'cycle': '4.2',
#   'release': datetime.date(2021, 3, 28),
#   'eol': datetime.date(2023, 10, 31),
#   'latest': '4.2.11',
#   'lts': False,
#   'description': 'Redmine 4.2, released on 2021-03-28, reaches EOL on 2023-10-31.'},
#  {'product': 'Redmine',
#   'cycle': '4.1',
#   'release': datetime.date(2019, 12, 20),
#   'eol': datetime.date(2022, 3, 28),
#   'latest': '4.1.7',
#   'lts': False,
#   'description': 'Redmine 4.1, released on 2019-12-20, reaches EOL on 2022-03-28.'},
#  {'product': 'Redmine',
#   'cycle': '4.0',
#   'release': datetime.date(2018, 12, 9),
#   'eol': datetime.date(2021, 4, 26),
#   'latest': '4.0.9',
#   'lts': False,
#   'description': 'Redmine 4.0, released on 2018-12-09, reaches EOL on 2021-04-26.'},
#  {'product': 'Red Hat Enterprise Linux',
#   'cycle': '10',
#   'release': datetime.date(2025, 5, 20),
#   'eol': datetime.date(2035, 5, 31),
#   'latest': '10.0',
#   'lts': datetime.date(2035, 5, 31),
#   'description': 'Red Hat Enterprise Linux 10, released on 2025-05-20, reaches EOL on 2035-05-31.'},
#  {'product': 'Red Hat Enterprise Linux',
#   'cycle': '9',
#   'release': datetime.date(2022, 5, 18),
#   'eol': datetime.date(2032, 5, 31),
#   'latest': '9.6',
#   'lts': datetime.date(2032, 5, 31),
#   'description': 'Red Hat Enterprise Linux 9, released on 2022-05-18, reaches EOL on 2032-05-31.'},
#  {'product': 'Red Hat Enterprise Linux',
#   'cycle': '8',
#   'release': datetime.date(2019, 5, 7),
#   'eol': datetime.date(2029, 5, 31),
#   'latest': '8.10',
#   'lts': datetime.date(2029, 5, 31),
#   'description': 'Red Hat Enterprise Linux 8, released on 2019-05-07, reaches EOL on 2029-05-31.'},
#  {'product': 'Red Hat Enterprise Linux',
#   'cycle': '7',
#   'release': datetime.date(2014, 6, 10),
#   'eol': datetime.date(2024, 6, 30),
#   'latest': '7.9',
#   'lts': datetime.date(2024, 6, 30),
#   'description': 'Red Hat Enterprise Linux 7, released on 2014-06-10, reaches EOL on 2024-06-30.'},
#  {'product': 'Red Hat Enterprise Linux',
#   'cycle': '6',
#   'release': datetime.date(2010, 11, 10),
#   'eol': datetime.date(2020, 11, 30),
#   'latest': '6.10',
#   'lts': datetime.date(2020, 11, 30),
#   'description': 'Red Hat Enterprise Linux 6, released on 2010-11-10, reaches EOL on 2020-11-30.'},
#  {'product': 'Red Hat Enterprise Linux',
#   'cycle': '5',
#   'release': datetime.date(2007, 3, 15),
#   'eol': datetime.date(2017, 3, 31),
#   'latest': '5.11',
#   'lts': datetime.date(2017, 3, 31),
#   'description': 'Red Hat Enterprise Linux 5, released on 2007-03-15, reaches EOL on 2017-03-31.'},
#  {'product': 'Red Hat Enterprise Linux',
#   'cycle': '4',
#   'release': datetime.date(2005, 2, 15),
#   'eol': datetime.date(2012, 2, 29),
#   'latest': '4.9',
#   'lts': False,
#   'description': 'Red Hat Enterprise Linux 4, released on 2005-02-15, reaches EOL on 2012-02-29.'},
#  {'product': 'Red Hat OpenShift',
#   'cycle': '4.19',
#   'release': datetime.date(2025, 6, 17),
#   'eol': datetime.date(2026, 12, 17),
#   'latest': '4.19.2',
#   'lts': False,
#   'description': 'Red Hat OpenShift 4.19, released on 2025-06-17, reaches EOL on 2026-12-17.'},
#  {'product': 'Red Hat OpenShift',
#   'cycle': '4.18',
#   'release': datetime.date(2025, 2, 25),
#   'eol': datetime.date(2026, 8, 25),
#   'latest': '4.18.19',
#   'lts': False,
#   'description': 'Red Hat OpenShift 4.18, released on 2025-02-25, reaches EOL on 2026-08-25.'},
#  {'product': 'Red Hat OpenShift',
#   'cycle': '4.17',
#   'release': datetime.date(2024, 10, 1),
#   'eol': datetime.date(2026, 4, 1),
#   'latest': '4.17.34',
#   'lts': False,
#   'description': 'Red Hat OpenShift 4.17, released on 2024-10-01, reaches EOL on 2026-04-01.'},
#  {'product': 'Red Hat OpenShift',
#   'cycle': '4.16',
#   'release': datetime.date(2024, 6, 27),
#   'eol': datetime.date(2025, 12, 27),
#   'latest': '4.16.43',
#   'lts': False,
#   'description': 'Red Hat OpenShift 4.16, released on 2024-06-27, reaches EOL on 2025-12-27.'},
#  {'product': 'Red Hat OpenShift',
#   'cycle': '4.15',
#   'release': datetime.date(2024, 2, 27),
#   'eol': datetime.date(2025, 8, 27),
#   'latest': '4.15.53',
#   'lts': False,
#   'description': 'Red Hat OpenShift 4.15, released on 2024-02-27, reaches EOL on 2025-08-27.'},
#  {'product': 'Red Hat OpenShift',
#   'cycle': '4.14',
#   'release': datetime.date(2023, 10, 31),
#   'eol': datetime.date(2025, 5, 1),
#   'latest': '4.14.53',
#   'lts': False,
#   'description': 'Red Hat OpenShift 4.14, released on 2023-10-31, reaches EOL on 2025-05-01.'},
#  {'product': 'Red Hat OpenShift',
#   'cycle': '4.13',
#   'release': datetime.date(2023, 5, 17),
#   'eol': datetime.date(2024, 11, 17),
#   'latest': '4.13.58',
#   'lts': False,
#   'description': 'Red Hat OpenShift 4.13, released on 2023-05-17, reaches EOL on 2024-11-17.'},
#  {'product': 'Red Hat OpenShift',
#   'cycle': '4.12',
#   'release': datetime.date(2023, 1, 17),
#   'eol': datetime.date(2024, 7, 17),
#   'latest': '4.12.77',
#   'lts': False,
#   'description': 'Red Hat OpenShift 4.12, released on 2023-01-17, reaches EOL on 2024-07-17.'},
#  {'product': 'Red Hat OpenShift',
#   'cycle': '4.11',
#   'release': datetime.date(2022, 8, 10),
#   'eol': datetime.date(2024, 2, 10),
#   'latest': '4.11.59',
#   'lts': False,
#   'description': 'Red Hat OpenShift 4.11, released on 2022-08-10, reaches EOL on 2024-02-10.'},
#  {'product': 'Red Hat OpenShift',
#   'cycle': '4.10',
#   'release': datetime.date(2022, 3, 10),
#   'eol': datetime.date(2023, 9, 10),
#   'latest': '4.10.67',
#   'lts': False,
#   'description': 'Red Hat OpenShift 4.10, released on 2022-03-10, reaches EOL on 2023-09-10.'},
#  {'product': 'Red Hat OpenShift',
#   'cycle': '4.9',
#   'release': datetime.date(2021, 10, 18),
#   'eol': datetime.date(2023, 4, 18),
#   'latest': '4.9.59',
#   'lts': False,
#   'description': 'Red Hat OpenShift 4.9, released on 2021-10-18, reaches EOL on 2023-04-18.'},
#  {'product': 'Red Hat OpenShift',
#   'cycle': '4.8',
#   'release': datetime.date(2021, 7, 27),
#   'eol': datetime.date(2023, 1, 27),
#   'latest': '4.8.57',
#   'lts': False,
#   'description': 'Red Hat OpenShift 4.8, released on 2021-07-27, reaches EOL on 2023-01-27.'},
#  {'product': 'Red Hat OpenShift',
#   'cycle': '4.7',
#   'release': datetime.date(2021, 2, 24),
#   'eol': datetime.date(2022, 8, 24),
#   'latest': '4.7.60',
#   'lts': False,
#   'description': 'Red Hat OpenShift 4.7, released on 2021-02-24, reaches EOL on 2022-08-24.'},
#  {'product': 'Red Hat OpenShift',
#   'cycle': '4.6',
#   'release': datetime.date(2020, 11, 9),
#   'eol': datetime.date(2022, 10, 27),
#   'latest': '4.6.62',
#   'lts': False,
#   'description': 'Red Hat OpenShift 4.6, released on 2020-11-09, reaches EOL on 2022-10-27.'},
#  {'product': 'Red Hat OpenShift',
#   'cycle': '4.5',
#   'release': datetime.date(2020, 7, 16),
#   'eol': datetime.date(2021, 7, 27),
#   'latest': '4.5.41',
#   'lts': False,
#   'description': 'Red Hat OpenShift 4.5, released on 2020-07-16, reaches EOL on 2021-07-27.'},
#  {'product': 'Red Hat OpenShift',
#   'cycle': '4.4',
#   'release': datetime.date(2020, 5, 18),
#   'eol': datetime.date(2021, 2, 24),
#   'latest': '4.4.33',
#   'lts': False,
#   'description': 'Red Hat OpenShift 4.4, released on 2020-05-18, reaches EOL on 2021-02-24.'},
#  {'product': 'Red Hat OpenShift',
#   'cycle': '4.3',
#   'release': datetime.date(2020, 2, 12),
#   'eol': datetime.date(2020, 10, 27),
#   'latest': '4.3.40',
#   'lts': False,
#   'description': 'Red Hat OpenShift 4.3, released on 2020-02-12, reaches EOL on 2020-10-27.'},
#  {'product': 'Red Hat OpenShift',
#   'cycle': '4.2',
#   'release': datetime.date(2019, 10, 29),
#   'eol': datetime.date(2020, 7, 13),
#   'latest': '4.2.36',
#   'lts': False,
#   'description': 'Red Hat OpenShift 4.2, released on 2019-10-29, reaches EOL on 2020-07-13.'},
#  {'product': 'Red Hat OpenShift',
#   'cycle': '4.1',
#   'release': datetime.date(2019, 6, 18),
#   'eol': datetime.date(2020, 5, 5),
#   'latest': '4.1.41',
#   'lts': False,
#   'description': 'Red Hat OpenShift 4.1, released on 2019-06-18, reaches EOL on 2020-05-05.'},
#  {'product': 'Red Hat JBoss Enterprise Application Platform',
#   'cycle': '8',
#   'release': datetime.date(2024, 2, 5),
#   'eol': datetime.date(2031, 2, 5),
#   'latest': '8.0.8.0',
#   'lts': False,
#   'description': 'Red Hat JBoss Enterprise Application Platform 8, released on 2024-02-05, reaches EOL on 2031-02-05.'},
#  {'product': 'Red Hat JBoss Enterprise Application Platform',
#   'cycle': '7',
#   'release': datetime.date(2016, 5, 1),
#   'eol': datetime.date(2025, 6, 30),
#   'latest': '7.4.22',
#   'lts': False,
#   'description': 'Red Hat JBoss Enterprise Application Platform 7, released on 2016-05-01, reaches EOL on 2025-06-30.'},
#  {'product': 'Red Hat JBoss Enterprise Application Platform',
#   'cycle': '6',
#   'release': datetime.date(2012, 6, 1),
#   'eol': datetime.date(2019, 6, 30),
#   'latest': '6.4.24',
#   'lts': False,
#   'description': 'Red Hat JBoss Enterprise Application Platform 6, released on 2012-06-01, reaches EOL on 2019-06-30.'},
#  {'product': 'Red Hat JBoss Enterprise Application Platform',
#   'cycle': '5',
#   'release': datetime.date(2009, 11, 1),
#   'eol': datetime.date(2016, 11, 30),
#   'latest': '5.2.0',
#   'lts': False,
#   'description': 'Red Hat JBoss Enterprise Application Platform 5, released on 2009-11-01, reaches EOL on 2016-11-30.'},
#  {'product': 'Red Hat JBoss Enterprise Application Platform',
#   'cycle': '4.3',
#   'release': datetime.date(2008, 1, 1),
#   'eol': datetime.date(2013, 1, 31),
#   'latest': '4.3.0 CP10',
#   'lts': False,
#   'description': 'Red Hat JBoss Enterprise Application Platform 4.3, released on 2008-01-01, reaches EOL on 2013-01-31.'},
#  {'product': 'Red Hat JBoss Enterprise Application Platform',
#   'cycle': '4.2',
#   'release': datetime.date(2007, 6, 1),
#   'eol': datetime.date(2012, 6, 30),
#   'latest': '4.2.0.CP09',
#   'lts': False,
#   'description': 'Red Hat JBoss Enterprise Application Platform 4.2, released on 2007-06-01, reaches EOL on 2012-06-30.'},
#  {'product': 'Redis',
#   'cycle': '8.0',
#   'release': datetime.date(2025, 5, 2),
#   'eol': 'TBD',
#   'latest': '8.0.3',
#   'lts': False,
#   'description': 'Redis 8.0, released on 2025-05-02, reaches EOL on TBD.'},
#  {'product': 'Redis',
#   'cycle': '7.4',
#   'release': datetime.date(2024, 7, 29),
#   'eol': datetime.date(2026, 11, 30),
#   'latest': '7.4.5',
#   'lts': False,
#   'description': 'Redis 7.4, released on 2024-07-29, reaches EOL on 2026-11-30.'},
#  {'product': 'Redis',
#   'cycle': '7.2',
#   'release': datetime.date(2023, 8, 15),
#   'eol': datetime.date(2026, 2, 28),
#   'latest': '7.2.10',
#   'lts': False,
#   'description': 'Redis 7.2, released on 2023-08-15, reaches EOL on 2026-02-28.'},
#  {'product': 'Redis',
#   'cycle': '7.0',
#   'release': datetime.date(2022, 4, 27),
#   'eol': datetime.date(2024, 7, 29),
#   'latest': '7.0.15',
#   'lts': False,
#   'description': 'Redis 7.0, released on 2022-04-27, reaches EOL on 2024-07-29.'},
#  {'product': 'Redis',
#   'cycle': '6.2',
#   'release': datetime.date(2021, 2, 22),
#   'eol': datetime.date(2025, 2, 28),
#   'latest': '6.2.19',
#   'lts': False,
#   'description': 'Redis 6.2, released on 2021-02-22, reaches EOL on 2025-02-28.'},
#  {'product': 'Redis',
#   'cycle': '6.0',
#   'release': datetime.date(2020, 4, 30),
#   'eol': datetime.date(2022, 5, 31),
#   'latest': '6.0.20',
#   'lts': False,
#   'description': 'Redis 6.0, released on 2020-04-30, reaches EOL on 2022-05-31.'},
#  {'product': 'Redis',
#   'cycle': '5.0',
#   'release': datetime.date(2018, 10, 17),
#   'eol': datetime.date(2022, 4, 27),
#   'latest': '5.0.14',
#   'lts': False,
#   'description': 'Redis 5.0, released on 2018-10-17, reaches EOL on 2022-04-27.'},
#  {'product': 'Red Hat build of OpenJDK',
#   'cycle': '21',
#   'release': datetime.date(2023, 11, 14),
#   'eol': datetime.date(2029, 12, 31),
#   'latest': '21.0.6.0.7-3',
#   'lts': False,
#   'description': 'Red Hat build of OpenJDK 21, released on 2023-11-14, reaches EOL on 2029-12-31.'},
#  {'product': 'Red Hat build of OpenJDK',
#   'cycle': '17',
#   'release': datetime.date(2021, 11, 11),
#   'eol': datetime.date(2027, 10, 31),
#   'latest': '17.0.14.0.7-3',
#   'lts': False,
#   'description': 'Red Hat build of OpenJDK 17, released on 2021-11-11, reaches EOL on 2027-10-31.'},
#  {'product': 'Red Hat build of OpenJDK',
#   'cycle': '11',
#   'release': datetime.date(2018, 10, 1),
#   'eol': datetime.date(2024, 10, 31),
#   'latest': '11.0.25.0.9-3',
#   'lts': False,
#   'description': 'Red Hat build of OpenJDK 11, released on 2018-10-01, reaches EOL on 2024-10-31.'},
#  {'product': 'Red Hat build of OpenJDK',
#   'cycle': '8',
#   'release': datetime.date(2014, 10, 1),
#   'eol': datetime.date(2026, 11, 30),
#   'latest': '1.8.0.442.b06-2',
#   'lts': False,
#   'description': 'Red Hat build of OpenJDK 8, released on 2014-10-01, reaches EOL on 2026-11-30.'},
#  {'product': 'Red Hat build of OpenJDK',
#   'cycle': '7',
#   'release': datetime.date(2007, 3, 15),
#   'eol': datetime.date(2020, 6, 30),
#   'latest': '1.7.0.261-2.6.22.2',
#   'lts': False,
#   'description': 'Red Hat build of OpenJDK 7, released on 2007-03-15, reaches EOL on 2020-06-30.'},
#  {'product': 'Red Hat build of OpenJDK',
#   'cycle': '6',
#   'release': datetime.date(2007, 3, 15),
#   'eol': datetime.date(2016, 12, 31),
#   'latest': '1.6.0.41-1.13.13.1',
#   'lts': False,
#   'description': 'Red Hat build of OpenJDK 6, released on 2007-03-15, reaches EOL on 2016-12-31.'}]

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

model = SentenceTransformer("all-MiniLM-L6-v2")  # small, fast

entries = parse_eol_markdown()
descriptions = [e["description"] for e in entries]
embeddings = model.encode(descriptions, show_progress_bar=True)
# Out:
# Batches: 100%|██████████| 190/190 [00:51<00:00,  3.68it/s]

# %%
import faiss

dimension = embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(np.array(embeddings))  # FAISS needs np.float32 arrays

# Save the index and entries
faiss.write_index(index, "eol_index.faiss")

import pickle
with open("eol_entries.pkl", "wb") as f:
    pickle.dump(entries, f)

# %%
# !ls -lrt
# Out:
# total 10000
# -rw-rw-rw-   1 codespace root           15 Jul  8 04:12 README.md
# -rw-rw-rw-   1 codespace codespace      64 Jul  8 04:22 requirements.txt
# -rw-rw-rw-   1 codespace codespace   40446 Jul  8 04:37 Notebook.ipynb
# drwxrwxrwx+ 14 codespace codespace    4096 Jul  8 05:22 endoflife.date
# -rw-rw-rw-   1 codespace codespace     204 Jul  8 05:57 history
# -rw-rw-rw-   1 codespace codespace   30865 Jul  8 06:06 Untitled.ipynb
# -rw-rw-rw-   1 codespace codespace 9323565 Jul  8 06:07 eol_index.faiss
# -rw-rw-rw-   1 codespace codespace  823104 Jul  8 06:07 eol_entries.pkl
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
import pickle
import faiss
import numpy as np
from sentence_transformers import SentenceTransformer



model = SentenceTransformer("all-MiniLM-L6-v2")  # small, fast

# Load index and entries
index = faiss.read_index("eol_index.faiss")
with open("eol_entries.pkl", "rb") as f:
    entries = pickle.load(f)

def search_eol(query):
    query_vec = model.encode([query])
    D, I = index.search(np.array(query_vec), k=3)
    for i in I[0]:
        result = entries[i]
        print(f"📦 {result['product']} {result['cycle']}")
        print(f"🛠 Released: {result['release']}")
        print(f"⏳ EOL: {result['eol']}")
        print(f"🧲 LTS: {result['lts']}\n")


model = SentenceTransformer("all-MiniLM-L6-v2")

def search_eol(query, entries, faiss_index, threshold=0.60):
    query_vec = model.encode([query])
    D, I = faiss_index.search(np.array(query_vec), k=3)

    scores = 1 / (1 + D[0])  # Convert L2 distance to similarity (approx)

    if scores[0] < threshold:
        print("❌ No strong match found for your query.")
        print("💡 Try rephrasing or check spelling.")
        print("🧩 Closest matches:")
        for idx, score in zip(I[0], scores):
            entry = entries[idx]
            print(f" - {entry['product']} {entry['cycle']} (confidence: {score:.2f})")
        return

    top_entry = entries[I[0][0]]
    print(f"✅ Found: {top_entry['product']} {top_entry['cycle']}")
    print(f"📅 Release: {top_entry['release']}")
    print(f"📆 EOL: {top_entry['eol']}")

search_eol("When does RHEL 7 reach end of life?")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 37
#      34     print(f"📅 Release: {top_entry['release']}")
#      35     print(f"📆 EOL: {top_entry['eol']}")
# ---> 37 search_eol("When does RHEL 7 reach end of life?")
#
# TypeError: search_eol() missing 2 required positional arguments: 'entries' and 'faiss_index'

# %%
# !pip install chromadb
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting chromadb
#   Downloading chromadb-1.0.15-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.0 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from chromadb) (2.11.7)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.4.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvicorn-0.35.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.22.5 in /home/codespace/.local/lib/python3.12/site-packages (from chromadb) (2.2.6)
# Collecting posthog<6.0.0,>=2.4.0 (from chromadb)
#   Downloading posthog-5.4.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/codespace/.local/lib/python3.12/site-packages (from chromadb) (4.13.2)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.22.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.8 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.34.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.34.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.34.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from chromadb) (0.21.2)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from chromadb) (7.7.0)
# Collecting importlib-resources (from chromadb)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting grpcio>=1.58.0 (from chromadb)
#   Downloading grpcio-1.73.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-4.3.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Downloading typer-0.16.0-py3-none-any.whl.metadata (15 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-33.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from chromadb) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.1.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from chromadb) (3.10.18)
# Requirement already satisfied: httpx>=0.27.0 in /home/codespace/.local/lib/python3.12/site-packages (from chromadb) (0.28.1)
# Collecting rich>=10.11.0 (from chromadb)
#   Downloading rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: jsonschema>=4.19.0 in /home/codespace/.local/lib/python3.12/site-packages (from chromadb) (4.24.0)
# Requirement already satisfied: requests<3.0,>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.32.3)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in /home/codespace/.local/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Collecting backoff>=1.10.0 (from posthog<6.0.0,>=2.4.0->chromadb)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: distro>=1.5.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2025.4.26)
# Requirement already satisfied: packaging>=19.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from build>=1.0.3->chromadb) (24.2)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: anyio in /home/codespace/.local/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/codespace/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (0.25.1)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb)
#   Downloading google_auth-2.40.3-py2.py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/codespace/.local/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb)
#   Downloading protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Requirement already satisfied: sympy in /home/codespace/.local/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.3)
# Collecting importlib-metadata<8.8.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting zipp>=3.20 (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading googleapis_common_protos-1.70.0-py3-none-any.whl.metadata (9.3 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.34.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.34.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.34.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.34.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb)
#   Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting opentelemetry-semantic-conventions==0.55b1 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.55b1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic>=1.9->chromadb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic>=1.9->chromadb) (0.4.1)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->chromadb)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.12/site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from tokenizers>=0.13.2->chromadb) (0.33.2)
# Requirement already satisfied: filelock in /home/codespace/.local/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/codespace/.local/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.6.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.1.5)
# Collecting click>=8.0.0 (from typer>=0.9.0->chromadb)
#   Downloading click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.6.4-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Collecting uvloop>=0.15.1 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvloop-0.21.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-1.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading websockets-15.0.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: sniffio>=1.1 in /home/codespace/.local/lib/python3.12/site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Downloading chromadb-1.0.15-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 54.9 MB/s eta 0:00:00:00:01
# Downloading posthog-5.4.0-py3-none-any.whl (105 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading bcrypt-4.3.0-cp39-abi3-manylinux_2_34_x86_64.whl (284 kB)
# Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Downloading grpcio-1.73.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 52.7 MB/s eta 0:00:00
# Downloading kubernetes-33.1.0-py2.py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 42.6 MB/s eta 0:00:00
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading google_auth-2.40.3-py2.py3-none-any.whl (216 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading mmh3-5.1.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (101 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Downloading onnxruntime-1.22.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 47.7 MB/s eta 0:00:00:00:01
# Downloading opentelemetry_api-1.34.1-py3-none-any.whl (65 kB)
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.34.1-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.34.1-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.34.1-py3-none-any.whl (55 kB)
# Downloading googleapis_common_protos-1.70.0-py3-none-any.whl (294 kB)
# Downloading opentelemetry_sdk-1.34.1-py3-none-any.whl (118 kB)
# Downloading opentelemetry_semantic_conventions-0.55b1-py3-none-any.whl (196 kB)
# Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading pybase64-1.4.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (71 kB)
# Downloading rich-14.0.0-py3-none-any.whl (243 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading typer-0.16.0-py3-none-any.whl (46 kB)
# Downloading click-8.2.1-py3-none-any.whl (102 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading uvicorn-0.35.0-py3-none-any.whl (66 kB)
# Downloading httptools-0.6.4-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (510 kB)
# Downloading uvloop-0.21.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 54.2 MB/s eta 0:00:00
# Downloading watchfiles-1.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (452 kB)
# Downloading websockets-15.0.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (182 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=pypika-0.48.9-py2.py3-none-any.whl size=53803 sha256=71db79ce3c931db727966a793cd352ec8f21dd4d0123cd864d1147fa9a78babd
#   Stored in directory: /home/codespace/.cache/pip/wheels/d5/3d/69/8d68d249cd3de2584f226e27fd431d6344f7d70fd856ebd01b
# Successfully built pypika
# Installing collected packages: pypika, flatbuffers, durationpy, zipp, websockets, uvloop, shellingham, pyproject_hooks, pybase64, pyasn1, protobuf, oauthlib, mmh3, mdurl, importlib-resources, humanfriendly, httptools, grpcio, click, cachetools, bcrypt, backoff, watchfiles, uvicorn, rsa, requests-oauthlib, pyasn1-modules, posthog, opentelemetry-proto, markdown-it-py, importlib-metadata, googleapis-common-protos, coloredlogs, build, rich, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, onnxruntime, google-auth, typer, opentelemetry-semantic-conventions, kubernetes, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-grpc, chromadb
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45/45 [chromadb]chromadb]kubernetes]antic-conventions]
# Successfully installed backoff-2.2.1 bcrypt-4.3.0 build-1.2.2.post1 cachetools-5.5.2 chromadb-1.0.15 click-8.2.1 coloredlogs-15.0.1 durationpy-0.10 flatbuffers-25.2.10 google-auth-2.40.3 googleapis-common-protos-1.70.0 grpcio-1.73.1 httptools-0.6.4 humanfriendly-10.0 importlib-metadata-8.7.0 importlib-resources-6.5.2 kubernetes-33.1.0 markdown-it-py-3.0.0 mdurl-0.1.2 mmh3-5.1.0 oauthlib-3.3.1 onnxruntime-1.22.0 opentelemetry-api-1.34.1 opentelemetry-exporter-otlp-proto-common-1.34.1 opentelemetry-exporter-otlp-proto-grpc-1.34.1 opentelemetry-proto-1.34.1 opentelemetry-sdk-1.34.1 opentelemetry-semantic-conventions-0.55b1 posthog-5.4.0 protobuf-5.29.5 pyasn1-0.6.1 pyasn1-modules-0.4.2 pybase64-1.4.1 pypika-0.48.9 pyproject_hooks-1.2.0 requests-oauthlib-2.0.0 rich-14.0.0 rsa-4.9.1 shellingham-1.5.4 typer-0.16.0 uvicorn-0.35.0 uvloop-0.21.0 watchfiles-1.1.0 websockets-15.0.1 zipp-3.23.0
